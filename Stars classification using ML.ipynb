# %% [markdown]
# # Workshop on AI in Space Exploration - Spartificial and G. H. Raisoni Institute of Engineering and Business Management, Jalgaon
#
#
# ***This notebook is particularly designed for "AI Applications in Space Exploration" Workshop by Spartificial Innovations Pvt Ltd. However, anyone is allowed to use it, but it's only good for complete beginners in Python and ML.
# Please contact team@spartificial.com or https://spartificial.com/ to know more***
#
#
#
# This Coding Workshop is a basic introduction to the students to the concept of Coding in Python, Data Analysis and Machine Learning for Space Exploration and Applications.
#
# #### This project is an high level introduction to our curated Complete Training and Internship Programs for AI and Space Sccience.
#
# The Training Programs are specially designed such that participants can learn the basics of how to apply their coding skills in the unique setting of space. Students will learn and apply their knowledge for more advance projects and build bigger applications! Meet fellow learners and take the first step to code in Space.
#
# Please visit https://spartificial.com/programs to know more about the program and get yourself registered.
#
# At the end of the Training Program, students will be able to:
#
# * Understand the basics of Python
# * Manipulate mathematical data with Numpy
# * Understand big dataset with Pandas
# * Understand machine learning pipelines
# * Building autonomous spacecraft vision system
# * Learn coding applications for space
# * Take part in building more complex and bigger projects in Space
#
# *Coding an software application is a technically challenging process, but not impossible. It does requires proficiency in different coding languages. Students will only learn the basics of Python coding language and Machine Learning in this course to get them started on this exciting journey!

# %% [markdown]
# # Day 1
#
# # <center> Star Type detection using Machine Learning - Project
#
#
# ![](https://cdn.mos.cms.futurecdn.net/VUoa6w8FTLjP4BJGJ9HSg8-970-80.jpg)
#
#
#
# ### In this tutorial, you will learn how to use basic functions and libraries used for data analysis and getting started with machine learning.
#
# #### Note: This lession will not be very comprehensive and you may face some problem understanding it if you are a complete beginner but we have attached links to all the official documents to make things easy for you. Hope you get enjoy it!!
#
#
# ## Dataset & Aim
#
# The objective of this project is to classify stars based on different features like it's color, luminosity etc.
#
# *Firstly, add this [dataset](https://www.kaggle.com/datasets/deepu1109/star-dataset) to kernel. It consists of some different features of stars based on which we need to classify the star types. Information on the target classes is given below,*
# - 0 $\rightarrow$ Brown Dwarf
# - 1 $\rightarrow$ Red Dwarf
# - 2 $\rightarrow$ White Dwarf
# - 3 $\rightarrow$ Main Sequence
# - 4 $\rightarrow$ Supergiants
# - 5 $\rightarrow$ Hypergiants
#
#
# <img src="https://cdn.britannica.com/17/143617-050-DA3F8537/diagram-Hertzsprung-Russell-Annie-Jump-Cannon-type-order.jpg" width="600" height="700">

# %% [markdown]
# ### Import Required libraries
# Note: It would probably will not be the first step to import required libraries because you don't even know what libraries you will need in your project. But it's completely okay to import the library only when you need it later in the code.

# %%
# Import os: means import operating system 
# import is a python keyword used to import libraries (libraries are a collection of many useful functions and classes for typically one type)
# https://docs.python.org/3/library/os.html
import os

# numpy is one of the most commonly used matrix manipulation library. Make sure to check out the official documentations for in-depth understanding
# https://numpy.org/doc/stable/user/whatisnumpy.html
import numpy as np

# Let's make an import in order to plot something
# we import matplotlib to plot the data
import matplotlib.pyplot as plt
# %matplotlib inline

# to handle dataframes
# https://pandas.pydata.org/docs/user_guide/index.html
import pandas as pd

# to visualize plots more beautifully 
# https://seaborn.pydata.org/tutorial.html
import seaborn as sns

# library for machine learning
# https://scikit-learn.org/stable/getting_started.html
import sklearn

# %% [markdown]
#
# ## Creating the data frame
# - *Let's read the csv file from the added dataset and create our dataframe.*

# %%
## Suppress Filter Warnings
import warnings
warnings.filterwarnings('ignore')

## Handeling the dataset - Pandas
import pandas as pd

## Create the data frame
dataset_path = "../input/star-dataset/6 class csv.csv"
star_df = pd.read_csv(dataset_path)
star_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %%
star_df.describe()
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %%
# pd.set_option("display.max_rows", None)
star_df.head(10)
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
# 5             2840          0.000650        0.1100                   16.98
# 6             2637          0.000730        0.1270                   17.22
# 7             2600          0.000400        0.0960                   17.40
# 8             2650          0.000690        0.1100                   17.45
# 9             2700          0.000180        0.1300                   16.05
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# ...

# %% [markdown]
# ### Observations
# 1) Dataset consists of 240 rows, 6 feature and 1 target columns,
# - *Absolute Temperature (in K)*
# - *Relative Luminosity (L/Lo)*
# - *Relative Radius (R/Ro)*
# - *Absolute Magnitude (Mv)*
# - *Star Color*
# - *Spectral Class*
# - *Star Type (Target classes)*
#
# Here,
# - *Lo = 3.828 x 10^26 Watts (Avg Luminosity of Sun)*
# - *Ro = 6.9551 x 10^8 m (Avg Radius of Sun)*
#
# 2) Two categorical features (object type) which will need some kind of encoding,
# - *Star Color*
# - *Spectral Class*

# %% [markdown]
# ## Details on object data type columns
#
# - *Let's begin with the Star color column*

# %%
## Check the input counts for star color 
print("Color                 Count\n-----------------------------\n",
star_df['Star color'].value_counts())

print("\n\n")

## Visulaising the Star color data
plt.figure(figsize = (13, 6))
color = pd.DataFrame(star_df['Star color'].value_counts().sort_values(ascending=False))
ax = sns.barplot(x = color.index, y = 'Star color' , data = color, palette='magma')
plt.title("Visualising Star Colors", color = "m", fontsize = 18)
plt.ylabel('Star color', color = 'b', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# Color                 Count
# -----------------------------
#  Red                   112
# Blue                   55
# Blue-white             26
# Blue White             10
# yellow-white            8
# White                   7
# Blue white              3
# Yellowish White         3
# white                   3
# Whitish                 2
# Orange                  2
# yellowish               2
# Pale yellow orange      1
# White-Yellow            1
# Blue                    1
# Yellowish               1
# Orange-Red              1
# Blue white              1
# Blue-White              1
# Name: Star color, dtype: int64

# %% [markdown]
# - Some colors are just repeated in different ways so it needs some cleaning
# - Red, Blue, Blue - White, Yellow - White and White are the most observed colors

# %%
## Simplest way of doing it manually 
star_df.replace({"Star color" : {"Blue-white" : "Blue-White", 
                                  "Blue White" : "Blue-White", 
                                  "Blue white" : "Blue-White", 
                                  "Blue white " : "Blue-White", 
                                  "Blue-White" : "Blue-White",
                                  "yellow-white" : "Yellow-White",
                                  "Yellowish White" : "Yellow-White",
                                  "yellowish" : "Yellow-White",
                                  "White-Yellow" : "Yellow-White",
                                  "Yellowish" : "Yellow-White",
                                  "white" : "White",
                                  "Whitish" : "White",
                                  "Blue " : "Blue",
                                  "Pale yellow orange" : "Red",
                                  "Orange" : "Red",
                                  "Orange-Red" : "Red"}},
                                  inplace = True)
print("Color           Count\n-----------------------------\n", star_df['Star color'].value_counts())
# Out:
# Color           Count
# -----------------------------
#  Red             116
# Blue             56
# Blue-White       41
# Yellow-White     15
# White            12
# Name: Star color, dtype: int64

# %% [markdown]
# - *We are done! All the repeated/similar type of colors have been merged together.*
#
# Now let's move on to 'Spectral Class' and hope that no more data cleaning is required!

# %%
print("Class Count\n-------------------\n", star_df['Spectral Class'].value_counts())
spectral_class = pd.DataFrame(star_df['Spectral Class'].value_counts().sort_values(ascending=False))

print("\n\n")

plt.figure(figsize=(10, 6))
ax = sns.barplot(x = spectral_class.index, y = 'Spectral Class' , data = spectral_class, palette='magma')
plt.title("Visualising Spectral Class", color = "m", fontsize = 18)
plt.ylabel('Spectral Class', color = 'b', fontsize = 15)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
ax = ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
# Out:
# Class Count
# -------------------
#  M    111
# B     46
# O     40
# A     19
# F     17
# K      6
# G      1
# Name: Spectral Class, dtype: int64

# %% [markdown]
# ## Tomorrow, we will see how to use this data to train our machine learning model and the Quiz

# %% [markdown]
# # Day 2
# ### Correlation in our data

# %%
fig, ax = plt.subplots(figsize = (8, 6), dpi = 90)
sns.heatmap(star_df.corr(), ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Check if data is balanced
#
# - *Balanced data means all the targets have same count*
# - *More similar the count of targets, more balanced is the data*

# %%
sns.countplot(star_df['Star type'], palette = "viridis")
# Out:
# <AxesSubplot:xlabel='Star type', ylabel='count'>

# %% [markdown]
# - *We have a very balanced data!*

# %%
## Features
X = star_df[["Temperature (K)", "Luminosity(L/Lo)", "Radius(R/Ro)", "Absolute magnitude(Mv)"]]

# %% [markdown]
# So, I think now you got some pretty good idea of what we are doing and how we are doing.
#
# A machine learning model typically requires two things, data that will be fed into the model and lables that we want as the output.
# So, in our case, we want to feed X into the model, and we want it to predict the star type, y.
#
# Above we prepared X, to feed into the model, and we have have understood what we want from our model.

# %%
X
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
# [240 rows x 4 columns]

# %% [markdown]
# ## As you can see, we have four independent features and based on them we will train our model to predict the type of star.

# %% [markdown]
# ### Now let's prepare y, our expected output from the model.

# %%
## Target
y = star_df['Star type']

y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 235    5
# 236    5
# 237    5
# 238    5
# 239    5
# Name: Star type, Length: 240, dtype: int64

# %% [markdown]
# ### What our labels signify?
# - 0 $\rightarrow$ Brown Dwarf
# - 1 $\rightarrow$ Red Dwarf
# - 2 $\rightarrow$ White Dwarf
# - 3 $\rightarrow$ Main Sequence
# - 4 $\rightarrow$ Supergiants
# - 5 $\rightarrow$ Hypergiants

# %% [markdown]
# ## Let's segregate the data into training and test
#
# #### it's a good pratice to divide your data into two sets, training set on which your model will be trained
# #### and testing set, on which your model will be tested

# %%
# Splitting the data into training and testing sets
from sklearn.model_selection import train_test_split

## Perform the split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
print("X_train \n", X_train)
print()
print("y_train \n", y_train)
# Out:
# X_train
#       Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)
# 36              6757           1.43000       1.12000                   2.410
# 140            13420           0.00059       0.00981                  13.670
# 61              3432           0.00067       0.19000                  16.940
# 22              7220           0.00017       0.01100                  14.230
# 118             6850      229000.00000    1467.00000                 -10.070
# ..               ...               ...           ...                     ...
# 106            24630      363000.00000      63.00000                  -5.830
# 14              2650           0.00060       0.14000                  11.782
# 92              4077           0.08500       0.79500                   6.228
# 179            24490      248490.00000    1134.50000                  -8.240
# 102            23000      127000.00000      36.00000                  -5.760
#
# [120 rows x 4 columns]
#
# y_train
# ...

# %% [markdown]
# # Machine Learning Pipeline
#
# ![](https://www.researchgate.net/profile/Benyamina-Hamza/publication/353620685/figure/fig1/AS:1051936119873536@1627812523439/Machine-learning-pipeline.ppm)

# %% [markdown]
#  ## Let's proceed with Machine Learning with Logistic Regression

# %% [markdown]
# ## Let's build and train our model

# %%
## For Logistic Regression
from sklearn.linear_model import LogisticRegression

## Build the Regressor
logreg = LogisticRegression(random_state=42, max_iter=1000)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# ### Our model is trained, let's check the results

# %%
## Metrics for evaluation of the model
from sklearn.metrics import classification_report

## Predictions + Report
predictions = logreg.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        19
#            1       1.00      0.90      0.95        20
#            2       0.84      1.00      0.91        21
#            3       1.00      0.74      0.85        19
#            4       0.87      1.00      0.93        20
#            5       1.00      0.90      0.95        21
#
#     accuracy                           0.93       120
#    macro avg       0.94      0.92      0.92       120
# weighted avg       0.94      0.93      0.92       120

# %% [markdown]
# ![](https://miro.medium.com/max/824/1*xMl_wkMt42Hy8i84zs2WGg.png)
#
# ![](https://inside-machinelearning.com/wp-content/uploads/2021/09/F1-Score.png)

# %% [markdown]
# ### We have built our model and checked our results. We got some satisfactory results of around 0.58 f1-score

# %% [markdown]
# ![](http://1.bp.blogspot.com/-5esBhsQbNBs/Xm_KagMAxHI/AAAAAAAAAw0/OYWXcBy_15kErOaa-HHqP_TZYFxqOCfzQCLcBGAsYHQ/s1600/mouse.gif)
#
# ### So, that's all for now. Hope you enjoyed it. Thank you for going through all the code. If you haven't understood some or any part of the code, please do not worry. We are taking care of that also as we have scheduled several training programs for this purpose.
#
# ### Please visit our training programs and workshops at www.spartificial.com/programs
